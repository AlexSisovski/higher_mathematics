# %% [markdown]
# ## Напишите код, который будет переводить полярные координаты в декартовы.

# %%
import matplotlib.pyplot as plt
import numpy as np

# %matplotlib inline

# %%
def polary_cart(R, p):
    x = R * np.cos(p)
    y = R * np.sin(p)
    return(x, y)

# %%
R = int(input('Введите радиус: '))
a = int(input('Введите угол: '))
x, y = polary_cart(10, 180)
print('x = {}, y = {}'.format(x, y))
# Out:
# Введите радиус: 10
# Введите угол: 180
# x = -5.984600690578581, y = -8.011526357338305

# %% [markdown]
# ## Напишите код, который будет рисовать график окружности в полярных координатах.

# %%
p = np.linspace(0,2*np.pi,100)
plt.polar(np.cos(p),np.sin(p))

# %% [markdown]
# ## Напишите код, который будет рисовать график отрезка прямой линии в полярных координатах.

# %%
x = np.arange(1, 5)
y = x
plt.polar(x, y)

# %% [markdown]
# ## Решите систему уравнений:
# y = x2 – 1
# exp(x) + x∙(1 – y) = 1

# %%
from scipy.optimize import fsolve

# %%
def f(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x - x*y - 1)

# %%
x1, y1 = fsolve(f, (1, 1))
print(x1, y1)
# Out:
# 1.0807145162638894e-13 -0.999999999999867

# %% [markdown]
# 𝑦=𝑥2−1 exp(x) + x∙(1 – y) > 1

# %%
def f1(p):
    x, y = p
    return (y - x**2 + 1, np.exp(x) + x - x*y - 1 > 0)

# %%
x1, y1 = fsolve(f1, (2, 5))
print(x1, y1)
# Out:
# 2.0 2.999999999995637
